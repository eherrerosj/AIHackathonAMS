# %%
#!/usr/bin/env python
# coding: utf-8
import codecs
import csv
import re
import sys
import numpy as np
import pandas as pd
from keras.models import load_model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from newspaper import Article
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from string import punctuation
csv.field_size_limit(sys.maxsize)
# Out:
# 9223372036854775807

# %%
# helper functions
def text_to_wordlist(text, remove_stopwords=False, stem_words=False):

    text = text.lower().split()

    if remove_stopwords:
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
    
    text = " ".join(text)

    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)

    if stem_words:
        text = text.split()
        stemmer = SnowballStemmer('english')
        stemmed_words = [stemmer.stem(word) for word in text]
        text = " ".join(stemmed_words)
        
    return text

def get_body(url):
    a = Article(url, language='en')
    a.download()
    a.parse()
    return u''.join(a.text).encode('utf-8').strip()

# %%
#do this only once while in production
model = load_model('./model.h5')

read = pd.read_csv('./data/train.csv')
texts = [str(row[1]) + str(row[2]) for row in read.values]
labels = read[["type"]].values

read = pd.read_csv('./data/test.csv')
test_texts = [str(row[1]) + str(row[2]) for row in read.values]
test_ids = read.index.values

# %%
# get input from backend
_input = { "title": "Brexit: David Davis 'pretty sure' of free trade deal - BBC News",
          "subtitle": "Pakistan oil tanker inferno kills at least 123",
          "description": "News",
          "website": "bbc.com",
          "poster": "BBC",
          "url": "http://www.bbc.com/news/uk-politics-40397312",
          "id": "world-south-asia-40396036" }

# %%
# get input from backend
_input = { "title": "Koch brothers plan stepped-up spending: ‘More optimistic now about what we can accomplish’",
           "url"  : "http://abcnews.go.com/International/wireStory/county-government-southwestern-china-100-people-40-homes-48248383"}

# %%
# clean input
text = [text_to_wordlist(_input['title'] + get_body(_input['url']))]
# tokenize input with train_data
tokenizer = Tokenizer(num_words=200000)
tokenizer.fit_on_texts(texts + test_texts + text)

# convert input to padded sequence
sequences = tokenizer.texts_to_sequences(text)
word_index = tokenizer.word_index
data = pad_sequences(sequences, maxlen=500)

# %%
# predict newsarticle validity
pred = model.predict([data], batch_size=1, verbose=0)

# output
output = {'id': _input['id'], 'prediction':int(round(pred[0][0])), 'confidence': pred[0][0]}

# %%
output
# Out:
# {'confidence': 0.88757902, 'id': 'world-south-asia-40396036', 'prediction': 1}

# %%
read
# Out:
#       Unnamed: 0                                              title  \
# 0           1514  Johnny Depp Spotted Wearing Fiancee Amber Hear...
# 1           1191               Film review: Muppets Most Wanted (U)
# 2           9806  Comment on After Fighting for Freedom, 76-yo V...
# 3           1748  OBAMA TRIES TO PASS LAST SECOND EXECUTIVE ORDE...
# 4           1748  Business group, Dem senator move to stymie nat...
# 5           1043  GERMAN ‘GESTAPO’ considers prosecuting parents...
# 6           1043     Reporter's Notebook: In Search of Flight MH370
# 7           5169  This Is What Gold Does In A Currency Crisis, B...
# 8           5169  Amazon 'not optimistic' about ending book stan...
# 9           8426  Trump Is Keeping His Promises, Cutting Taxes, ...
# 10          8426  Matt Damon Pours Toilet Water on Himself for A...
# 11          6048  Michelle Runs Her Nasty Mouth At Trump, Then K...
# 12          6048  Sector Update: Info Tech; BlackBerry to Launch...
# 13          4794  NYTimes Editor Defends Paper's Coverage of Tru...
# 14          4794  In 'Pulse Flow,' Colorado River Reaches Its De...
# 15         11404  Project Veritas: Bartender who recorded Romney...
# 16          8793  Blueprint for social control: The brutal legac...
# 17          3079  Amnesty International Slams Obama Gov for Kill...
# 18          3079  Rita Ora Ruins Dress And Sneakers During 'Fall...
# 19          7201  Trump’s Campaign Backfires As Hillary Clinton ...
# 20          7201  Video: Nicki Minaj Performs at 'Philly 4th of ...
# 21          9867  This is the Man Militarized Police at Standing...
# 22          2107                 Memetic Wednesday: Endgame Hillary
# 23          2107       BMW recalls 156000 cars in US over bad bolts
# 24           832  Putin Rejects Russian Army’s Calls to Resume A...
# 25           832  US home sales fall, but consumer confidence hi...
# 26          7470  Russian warships ready to strike terrorists ne...
# 27          7470         US Fed eyes October end of asset purchases
# 28          7317  Минобороны России: Эвакуация жителей Алеппо бы...
# 4085  Leave a Reply Click here to get more info on f...
# 4086  Keywords: beauty , blackheads , blackheads tre...
# 4087  Wednesday night’s debut show of Beyoncé and Ja...
# 4088  Post was not sent - check your email addresses...
# 4089  Another year, another season and a lot of deat...
# 4090  26 WikiLeaks bombshells on Hillary you need to...
# 4091  Posted on November 11, 2016 by Charles Hugh Sm...
# 4092   What Does it Take to Bring Hillary Clinton to...
# 4093  All the action as it happened on the water on ...
# 4094  Steven Seagal receives Russian citizenship on ...
# 4095  Page not found\n\nWe’re sorry. The page you we...
# 4096  2016 presidential campaign by Matt Sedillo Hil...
# 4097  [UPDATE] Following the publication of this sto...
# 4098  November 24 ,2016 BY AHT Staff Egypt Says No t...
# 4099  Grad students continue push for union\n\nBy Ja...
# 4100  Email Donald Trump’s inauguration may be month...
# 4101  In a study that now seems embarrassingly overd...
# 4102  Posted on November 7, 2016 by DavidSwanson 1. ...
# 4103  President al-Assad: United States and its West...
# 4104  3 Philadelphia prison guards arrested for alle...
# 4105  A 17-year old girl was allegedly raped during ...
# 4106  Thursday 10 November 2016 John Lewis offers st...
# 4107  A flying saucer landed with an enormous splash...
# 4108    Edmondo Burr in News , US // 0 Comments Adam...
# 4109  In what is being hailed as a ‘ truly astonishi...
# 4110  Mick Jagger has had a really tough year. Earli...
# 4111  Financial markets jolted as US election polls ...
# 4112  If you don't like hot and humid weather, you'r...
#
#                            site_url  type
# 0                     ibtimes.co.uk   0.0
# 1        yorkshireeveningpost.co.uk   0.0
# 2         thefreethoughtproject.com   1.0
# 3         conservativedailypost.com   1.0
# 4                   dailycaller.com   0.0
# 5                barenakedislam.com   1.0
# 6                      live.wsj.com   0.0
# 7           investmentwatchblog.com   1.0
# 8                       pcworld.com   0.0
# 9                     sgtreport.com   1.0
# 10             chicago.cbslocal.com   0.0
# 11                 madworldnews.com   1.0
# 12                       nasdaq.com   0.0
# 13                          ijr.com   1.0
# 14                thinkprogress.org   0.0
# 15                      twitchy.com   1.0
# 16                         sott.net   1.0
# 17                      eutimes.net   1.0
# 18                    style.mtv.com   0.0
# 19                 politicususa.com   1.0
# 20                 directlyrics.com   0.0
# 21             themindunleashed.com   1.0
# 22                 dailystormer.com   1.0
# 23                    slashgear.com   0.0
# 24                      antiwar.com   1.0
# 25                    money.msn.com   0.0
# 26                 pravdareport.com   1.0
# 27                shanghaidaily.com   0.0
# 28                        pravda.ru   1.0
# 29                 sciencecodex.com   0.0
# ...                             ...   ...
# 4083                    disclose.tv   1.0
# 4084                       hngn.com   0.0
# 4085                    thesaker.is   1.0
# 4086                naturalnews.com   1.0
# 4087                    pagesix.com   0.0
# 4088          libertyblitzkrieg.com   1.0
# 4089                dailycaller.com   0.0
# 4090                        wnd.com   1.0
# 4091            washingtonsblog.com   1.0
# 4092  informationclearinghouse.info   1.0
# 4093                    3news.co.nz   0.0
# 4094               pravdareport.com   1.0
# 4095                startribune.com   0.0
# 4096          blackagendareport.com   1.0
# 4097                   gamespot.com   0.0
# 4098                  ahtribune.com   1.0
# 4099                   pittnews.com   0.0
# 4100                  clickhole.com   1.0
# 4101                        io9.com   0.0
# 4102            washingtonsblog.com   1.0
# 4103                    thesaker.is   1.0
# 4104                       rinf.com   1.0
# 4105                      z6mag.com   0.0
# 4106                  newsthump.com   1.0
# 4107            natureworldnews.com   0.0
# 4108               yournewswire.com   1.0
# 4109                libertynews.com   1.0
# 4110                  inquisitr.com   0.0
# 4111            nakedcapitalism.com   1.0
# 4112                     eather.com   0.0
#
# [4113 rows x 5 columns]
